# %%
# Lesson 2: Sequential Chats and Customer Onboarding

## Setup

from utils import get_openai_api_key
OPENAI_API_KEY = get_openai_api_key()
llm_config={"model": "gpt-3.5-turbo"}

from autogen import ConversableAgent

## Creating the needed agents

onboarding_personal_information_agent = ConversableAgent(
    name="Onboarding Personal Information Agent",
    system_message='''You are a helpful customer onboarding agent,
    you are here to help new customers get started with our product.
    Your job is to gather customer's name and location.
    Do not ask for other information. Return 'TERMINATE' 
    when you have gathered all the information.''',
    llm_config=llm_config,
    code_execution_config=False,
    human_input_mode="NEVER",
)

onboarding_topic_preference_agent = ConversableAgent(
    name="Onboarding Topic preference Agent",
    system_message='''You are a helpful customer onboarding agent,
    you are here to help new customers get started with our product.
    Your job is to gather customer's preferences on news topics.
    Do not ask for other information.
    Return 'TERMINATE' when you have gathered all the information.''',
    llm_config=llm_config,
    code_execution_config=False,
    human_input_mode="NEVER",
)

customer_engagement_agent = ConversableAgent(
    name="Customer Engagement Agent",
    system_message='''You are a helpful customer service agent
    here to provide fun for the customer based on the user's
    personal information and topic preferences.
    This could include fun facts, jokes, or interesting stories.
    Make sure to make it engaging and fun!
    Return 'TERMINATE' when you are done.''',
    llm_config=llm_config,
    code_execution_config=False,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "terminate" in msg.get("content").lower(),
)

customer_proxy_agent = ConversableAgent(
    name="customer_proxy_agent",
    llm_config=False,
    code_execution_config=False,
    human_input_mode="ALWAYS",
    is_termination_msg=lambda msg: "terminate" in msg.get("content").lower(),
)

## Creating tasks

# Now, you can craft a series of tasks to facilitate the onboarding process.

chats = [
    {
        "sender": onboarding_personal_information_agent,
        "recipient": customer_proxy_agent,
        "message": 
            "Hello, I'm here to help you get started with our product."
            "Could you tell me your name and location?",
        "summary_method": "reflection_with_llm",
        "summary_args": {
            "summary_prompt" : "Return the customer information "
                             "into as JSON object only: "
                             "{'name': '', 'location': ''}",
        },
        "max_turns": 2,
        "clear_history" : True
    },
    {
        "sender": onboarding_topic_preference_agent,
        "recipient": customer_proxy_agent,
        "message": 
                "Great! Could you tell me what topics you are "
                "interested in reading about?",
        "summary_method": "reflection_with_llm",
        "max_turns": 1,
        "clear_history" : False
    },
    {
        "sender": customer_proxy_agent,
        "recipient": customer_engagement_agent,
        "message": "Let's find something fun to read.",
        "max_turns": 1,
        "summary_method": "reflection_with_llm",
    },
]

## Start the onboarding process


from autogen import initiate_chats

chat_results = initiate_chats(chats)

## Print out the summary

for chat_result in chat_results:
    print(chat_result.summary)
    print("\n")

## Print out the cost

for chat_result in chat_results:
    print(chat_result.cost)
    print("\n")
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Onboarding Personal Information Agent (to customer_proxy_agent):
#
# Hello, I'm here to help you get started with our product.Could you tell me your name and location?
#
# --------------------------------------------------------------------------------
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/agentchat/chat.py:51: UserWarning: Repetitive recipients detected: The chat history will be cleared by default if a recipient appears more than once. To retain the chat history, please set 'clear_history=False' in the configuration of the repeating agent.
#   warnings.warn(
# customer_proxy_agent (to Onboarding Personal Information Agent):
#
# cha
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/oai/client.py:302, in OpenAIClient._handle_openai_bad_request_error.<locals>.wrapper(*args, **kwargs)
#     301 try:
# --> 302     return func(*args, **kwargs)
#     303 except openai.BadRequestError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openai/resources/chat/completions.py:850, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     849 validate_response_format(response_format)
# --> 850 return self._post(
#     851     "/chat/completions",
#     852     body=maybe_transform(
#     853         {
#     854             "messages": messages,
#     855             "model": model,
#     856             "audio": audio,
#     857             "frequency_penalty": frequency_penalty,
#     858             "function_call": function_call,
#     859             "functions": functions,
#     860             "logit_bias": logit_bias,
#     861             "logprobs": logprobs,
#     862             "max_completion_tokens": max_completion_tokens,
#     863             "max_tokens": max_tokens,
#     864             "metadata": metadata,
#     865             "modalities": modalities,
#     866             "n": n,
#     867             "parallel_tool_calls": parallel_tool_calls,
#     868             "prediction": prediction,
#     869             "presence_penalty": presence_penalty,
#     870             "reasoning_effort": reasoning_effort,
#     871             "response_format": response_format,
#     872             "seed": seed,
#     873             "service_tier": service_tier,
#     874             "stop": stop,
#     875             "store": store,
#     876             "stream": stream,
#     877             "stream_options": stream_options,
#     878             "temperature": temperature,
#     879             "tool_choice": tool_choice,
#     880             "tools": tools,
#     881             "top_logprobs": top_logprobs,
#     882             "top_p": top_p,
#     883             "user": user,
#     884         },
#     885         completion_create_params.CompletionCreateParams,
#     886     ),
#     887     options=make_request_options(
#     888         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     889     ),
#     890     cast_to=ChatCompletion,
#     891     stream=stream or False,
#     892     stream_cls=Stream[ChatCompletionChunk],
#     893 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openai/_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1280 opts = FinalRequestOptions.construct(
#    1281     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282 )
# -> 1283 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openai/_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openai/_base_client.py:1064, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1063     log.debug("Re-raising status error")
# -> 1064     raise self._make_status_error_from_response(err.response) from None
#    1066 return self._process_response(
#    1067     cast_to=cast_to,
#    1068     options=options,
#    (...)
#    1072     retries_taken=retries_taken,
#    1073 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "Invalid 'messages[1].name': string does not match pattern. Expected a string that matches the pattern '^[a-zA-Z0-9_-]+$'.", 'type': 'invalid_request_error', 'param': 'messages[1].name', 'code': 'invalid_value'}}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 103
#      98 ## Start the onboarding process
#     101 from autogen import initiate_chats
# --> 103 chat_results = initiate_chats(chats)
#     105 ## Print out the summary
#     107 for chat_result in chat_results:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/agentchat/chat.py:190, in initiate_chats(chat_queue)
#     187         __post_carryover_processing(chat_info)
#     189     sender = chat_info["sender"]
# --> 190     chat_res = sender.initiate_chat(**chat_info)
#     191     finished_chats.append(chat_res)
#     192 return finished_chats
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:1115, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1113         msg2send = self.generate_init_message(message, **kwargs)
#    1114 else:
# -> 1115     msg2send = self.generate_reply(messages=self.chat_messages[recipient], sender=recipient)
#    1116 if msg2send is None:
#    1117     break
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:2066, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2064     continue
#    2065 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2066     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2067     if logging_enabled():
#    2068         log_event(
#    2069             self,
#    2070             "reply_func_executed",
#    (...)
#    2074             reply=reply,
#    2075         )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:1443, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1441 if messages is None:
#    1442     messages = self._oai_messages[sender]
# -> 1443 extracted_response = self._generate_oai_reply_from_client(
#    1444     client, self._oai_system_message + messages, self.client_cache
#    1445 )
#    1446 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:1462, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1459         all_messages.append(message)
#    1461 # TODO: #1143 handle token limit exceeded error
# -> 1462 response = llm_client.create(
#    1463     context=messages[-1].pop("context", None),
#    1464     messages=all_messages,
#    1465     cache=cache,
#    1466     agent=self,
#    1467 )
#    1468 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1470 if extracted_response is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/oai/client.py:964, in OpenAIWrapper.create(self, **config)
#     962 try:
#     963     request_ts = get_current_ts()
# --> 964     response = client.create(params)
#     965 except APITimeoutError as err:
#     966     logger.debug(f"config {i} timed out", exc_info=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/oai/client.py:468, in OpenAIClient.create(self, params)
#     466     self._process_reasoning_model_params(params)
#     467 params["stream"] = False
# --> 468 response = create_or_parse(**params)
#     469 # remove the system_message from the response and add it in the prompt at the start.
#     470 if is_o1:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/autogen/oai/client.py:314, in OpenAIClient._handle_openai_bad_request_error.<locals>.wrapper(*args, **kwargs)
#     307     if OpenAIClient._is_agent_name_error_message(response_json["error"]["message"]):
#     308         error_message = (
#     309             f"This error typically occurs when the agent name contains invalid characters, such as spaces or special symbols.\n"
#     310             "Please ensure that your agent name follows the correct format and doesn't include any unsupported characters.\n"
#     311             "Check the agent name and try again.\n"
#     312             f"Here is the full BadRequestError from openai:\n{e.message}."
#     313         )
# --> 314         raise ValueError(error_message)
#     316 raise e
#
# ValueError: This error typically occurs when the agent name contains invalid characters, such as spaces or special symbols.
# Please ensure that your agent name follows the correct format and doesn't include any unsupported characters.
# Check the agent name and try again.
# Here is the full BadRequestError from openai:
# Error code: 400 - {'error': {'message': "Invalid 'messages[1].name': string does not match pattern. Expected a string that matches the pattern '^[a-zA-Z0-9_-]+$'.", 'type': 'invalid_request_error', 'param': 'messages[1].name', 'code': 'invalid_value'}}.
